# %% [markdown]
# # Computational Drug Discovery
# ## Download Bioactivity Data

# %% [markdown]
# In this Jupyter notebook, we will be building a real-life data science project that you can include in your data science portfolio. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.

# %% [markdown]
# ### ChEMBL Database

# %% [markdown]
# The [ChEMBL Database](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2.4 million compounds. It is compiled from more than 89,000 documents, 1.6 million assays and the data spans 15,000 targets and 2,000 cells and 48,000 indications. [Data as of Nov 05, 2024; ChEMBL version 34].

# %% [markdown]
# ### Installing libraries

# %% [markdown]
# *pip install chembl-webresource-client*

# %% [markdown]
# ### Importing libraries

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## Search for Target protein

# %% [markdown]
# ### Target search for coronavirus

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 7                                                 []
# 8  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 9                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                 Feline coronavirus
# 2                                 Murine coronavirus
# 3                                 Canine coronavirus
# 4                             Human coronavirus 229E
# 5                             Human coronavirus OC43
# ...

# %% [markdown]
# ### Select and retrieve bioactivity data for Replicase polyprotein 1ab (9th entry)

# %% [markdown]
# We will assign the 9th entry (which corresponds to the target protein, Replicase polyprotein 1ab) to the selected_target variable

# %%
selected_target = targets.target_chembl_id[9]
selected_target
# Out:
# 'CHEMBL4523582'

# %% [markdown]
# Here, we will retrieve only bioactivity data for Replicase polyprotein 1ab (CHEMBL4523582) that are reported as IC-50
#  values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None  Dtt Insensitive     19964199                  []
# 1        None  Dtt Insensitive     19964200                  []
# 2        None  Dtt Insensitive     19964201                  []
# 3        None  Dtt Insensitive     19964202                  []
# 4        None  Dtt Insensitive     19964203                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL4495583  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...
# 1   CHEMBL4495583  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...
# 2   CHEMBL4495583  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...
# 3   CHEMBL4495583  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...
# 4   CHEMBL4495583  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000190  ...
# ...

# %%
df.shape
# Out:
# (1538, 46)

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv.**

# %%
#df.to_csv('RP1ab_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ### Handling missing data

# %% [markdown]
# If any compounds has missing value for the **standard_value**  and **canonical_smiles** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# C:\Users\a_als\AppData\Local\Temp\ipykernel_34732\3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None  Dtt Insensitive
# 1                                                  None  Dtt Insensitive
# 2                                                  None  Dtt Insensitive
# 3                                                  None  Dtt Insensitive
# 4                                                  None  Dtt Insensitive
# ...                                                 ...              ...
# 1533  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1534  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1535  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1136

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None  Dtt Insensitive
# 1                                                  None  Dtt Insensitive
# 2                                                  None  Dtt Insensitive
# 3                                                  None  Dtt Insensitive
# 4                                                  None  Dtt Insensitive
# ...                                                 ...              ...
# 1530  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1531  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1532  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1536  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1537  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# ...

# %% [markdown]
# ### Data pre-processing of the bioactivity data

# %% [markdown]
# Combine the 3 columns (molecule_chembl_id, canonical_smiles, standard_value) and bioactivity_class into a DataFrame

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0             CHEMBL480   Cc1c(OCC(F)(F)F)ccnc1C[S+]([O-])c1nc2ccccc2[nH]1
# 1          CHEMBL178459                              Cc1c(-c2cnccn2)ssc1=S
# 2         CHEMBL3545157            O=c1sn(-c2cccc3ccccc23)c(=O)n1Cc1ccccc1
# 3          CHEMBL297453  O=C(O[C@@H]1Cc2c(O)cc(O)cc2O[C@@H]1c1cc(O)c(O)...
# 4         CHEMBL4303595                            O=C1C=Cc2cc(Br)ccc2C1=O
# ...                 ...                                                ...
# 1530      CHEMBL5286307  CC(C)(C)[C@H](NC(=O)C(F)(F)F)C(=O)N1[C@@H]2CCC...
# 1531      CHEMBL5282079  CC(C)(C)[C@H](NS(=O)(=O)C(F)(F)F)C(=O)N1C[C@H]...
# 1532      CHEMBL5275584  Cn1cnc2c1c(=O)n(CC(=O)Nc1ccc(S(=O)(=O)Nc3ncccn...
# 1536      CHEMBL5281103  Cn1c(=O)c2c(nc3n(CC#Cc4ccc(Cl)c(Cl)c4)ccn23)n(...
# 1537      CHEMBL5268256  O=c1[nH]cc(-c2cc(-c3cccc(Cl)c3)c(=O)n(-c3cccnc...
#
#      standard_value
# 0             390.0
# 1             210.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
#df3.to_csv('RP1ab_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### Labeling compounds as either being active, inactive or intermediate

# %% [markdown]
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be active while those greater than 10,000 nM will be considered to be inactive. As for those values in between 1,000 and 10,000 nM will be referred to as intermediate.

# %%
df4 = pd.read_csv('RP1ab_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0             CHEMBL480   Cc1c(OCC(F)(F)F)ccnc1C[S+]([O-])c1nc2ccccc2[nH]1
# 1          CHEMBL178459                              Cc1c(-c2cnccn2)ssc1=S
# 2         CHEMBL3545157            O=c1sn(-c2cccc3ccccc23)c(=O)n1Cc1ccccc1
# 3          CHEMBL297453  O=C(O[C@@H]1Cc2c(O)cc(O)cc2O[C@@H]1c1cc(O)c(O)...
# 4         CHEMBL4303595                            O=C1C=Cc2cc(Br)ccc2C1=O
# ...                 ...                                                ...
# 1131      CHEMBL5286307  CC(C)(C)[C@H](NC(=O)C(F)(F)F)C(=O)N1[C@@H]2CCC...
# 1132      CHEMBL5282079  CC(C)(C)[C@H](NS(=O)(=O)C(F)(F)F)C(=O)N1C[C@H]...
# 1133      CHEMBL5275584  Cn1cnc2c1c(=O)n(CC(=O)Nc1ccc(S(=O)(=O)Nc3ncccn...
# 1134      CHEMBL5281103  Cn1c(=O)c2c(nc3n(CC#Cc4ccc(Cl)c(Cl)c4)ccn23)n(...
# 1135      CHEMBL5268256  O=c1[nH]cc(-c2cc(-c3cccc(Cl)c3)c(=O)n(-c3cccnc...
#
#       standard_value         class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
#df5.to_csv('RP1ab_03_bioactivity_data_curated.csv', index=False)
